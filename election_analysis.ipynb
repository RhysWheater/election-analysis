# %% [markdown]
# I have downloaded UK election results from 1918 (widely considered the first in the modern democratic era) to 2019

# %% [markdown]
# ### Importing dependencies

# %%
import pandas as pd

# %% [markdown]
# ## Initial Look at the Data

# %% [markdown]
# Let's start by loading the election data into a df:

# %%
def load_election_results_csv():
    return pd.read_csv("1918-2019election_results.csv", encoding="ISO-8859-1")
df = load_election_results_csv()

# %%
df.columns
# Out:
# Index(['constituency_id', 'seats', 'constituency_name', 'country/region',
#        'electorate', 'con_votes', 'con_share', 'lib_votes ', 'lib_share',
#        'lab_votes', 'lab_share', 'natSW_votes', 'natSW_share', 'oth_votes',
#        'oth_share', 'total_votes', 'turnout ', 'election', 'boundary_set',
#        'Unnamed: 19'],
#       dtype='object')

# %% [markdown]
# Most of these are self-explanatory. **con_votes**, **lib_votes** and **lab_votes** refer to the number of votes received for each of the three large parties of the past century: Conservative, Liberal and Labour. **natSW_votes** refers to Scottish and Welsh nationalist parties, while **oth_votes** totals all votes for all other parties.

# %% [markdown]
# ### Fixing Data Weirdness
#
# #### Whitespace in Field Names
#
# Weirdly **lib_votes** and **turnout** have some whitespace after them, they're the only field names with that so let's fix them to avoid errors later:

# %%
df.rename(columns={"lib_votes ": "lib_votes"}, inplace=True)
df.rename(columns={"turnout ": "turnout"}, inplace=True)

# %%
df.head()
# Out:
#   constituency_id  seats  constituency_name country/region electorate  \
# 0             NaN      1   Belfast Victoria        Ireland      19494
# 1             NaN      1             Carlow        Ireland        NaN
# 2             NaN      1         Cavan East        Ireland        NaN
# 3             NaN      1         Clare West        Ireland        NaN
# 4             NaN      2          Cork City        Ireland      45017
#
#    con_votes  con_share lib_votes  lib_share lab_votes  lab_share  \
# 0        NaN        NaN       NaN        NaN       NaN        NaN
# 1        NaN        NaN       NaN        NaN       NaN        NaN
# 2        NaN        NaN       NaN        NaN       NaN        NaN
# 3        NaN        NaN       NaN        NaN       NaN        NaN
# 4     2519.0      0.082       NaN        NaN       NaN        NaN
#
#    natSW_votes  natSW_share  oth_votes  oth_share total_votes  turnout  \
# 0          NaN          NaN    13317.0      1.000       13317    0.683
# 1          NaN          NaN       -1.0      1.000          -1      NaN
# 2          NaN          NaN       -1.0      1.000          -1      NaN
# 3          NaN          NaN       -1.0      1.000          -1      NaN
# 4          NaN          NaN    28281.0      0.918       30800    0.684
#
#   election boundary_set Unnamed: 19
# 0     1918    1918-1935         NaN
# 1     1918    1918-1935         NaN
# 2     1918    1918-1935         NaN
# 3     1918    1918-1935         NaN
# 4     1918    1918-1935         NaN

# %% [markdown]
# #### Multiple Seat Constituencies

# %% [markdown]
# There's some interesting fields in here. The first weirdness is that Cork City has 2 seats. Prior to WW2, some UK constituencies returned 2 seats, these were usually university towns. These were not proportional constituencies, they were allocated to the cadidates in order of the nuber of votes they received and could in fact lead to a far more disproportionate result than "pure" FPTP does. Since these seats will distort my analysis somewhat, I would like to be able to exclude those cities with more than 1 seat. Let's see how many of them there were in the 1918 election:

# %%
constituencies_results_1918 = df[df["election"] == 1918]

# %%
constituencies_results_1918
# Out:
# Empty DataFrame
# Columns: [constituency_id, seats, constituency_name, country/region, electorate, con_votes, con_share, lib_votes, lib_share, lab_votes, lab_share, natSW_votes, natSW_share, oth_votes, oth_share, total_votes, turnout, election, boundary_set, Unnamed: 19]
# Index: []

# %% [markdown]
# That's weird, I wonder if the election field is stored as a string instead of a number.

# %%
constituencies_results_1918 = df[df["election"] == "1918"]

# %%
constituencies_results_1918
# Out:
#     constituency_id  seats                         constituency_name  \
# 0               NaN      1                          Belfast Victoria
# 1               NaN      1                                    Carlow
# 2               NaN      1                                Cavan East
# 3               NaN      1                                Clare West
# 4               NaN      2                                 Cork City
# ..              ...    ...                                       ...
# 683             509      1           Yorkshire (West Riding) Skipton
# 684             510      1           Yorkshire (West Riding) Sowerby
# 685             511      1       Yorkshire (West Riding) Spen Valley
# 686             512      1         Yorkshire (West Riding) Wentworth
# 687             504      1  Yorkshire (West Riding) Pudsey And Otley
#
#                country/region electorate  con_votes  con_share lib_votes  \
# 0                     Ireland      19494        NaN        NaN       NaN
# 1                     Ireland        NaN        NaN        NaN       NaN
# 2                     Ireland        NaN        NaN        NaN       NaN
# 3                     Ireland        NaN        NaN        NaN       NaN
# 4                     Ireland      45017     2519.0      0.082       NaN
# ..                        ...        ...        ...        ...       ...
# 683  Yorkshire and the Humber      35722    12599.0      0.550     10318
# 684  Yorkshire and the Humber      34286        NaN        NaN      6778
# 685  Yorkshire and the Humber      38827        NaN        NaN       NaN
# 686  Yorkshire and the Humber      36004     5315.0      0.244      3453
# 687  Yorkshire and the Humber      31487        NaN        NaN       NaN
#
#      lib_share lab_votes  lab_share  natSW_votes  natSW_share  oth_votes  \
# 0          NaN       NaN        NaN          NaN          NaN    13317.0
# 1          NaN       NaN        NaN          NaN          NaN       -1.0
# 2          NaN       NaN        NaN          NaN          NaN       -1.0
# 3          NaN       NaN        NaN          NaN          NaN       -1.0
# 4          NaN       NaN        NaN          NaN          NaN    28281.0
# ..         ...       ...        ...          ...          ...        ...
# 683      0.450       NaN        NaN          NaN          NaN        NaN
# 684      0.303      7306      0.327          NaN          NaN     8287.0
# 685        NaN      8508      0.444          NaN          NaN    10664.0
# 686      0.158     13029      0.598          NaN          NaN        NaN
# 687        NaN      4583      0.248          NaN          NaN    13860.0
#
#      oth_share total_votes  turnout election boundary_set Unnamed: 19
# 0        1.000       13317    0.683     1918    1918-1935         NaN
# 1        1.000          -1      NaN     1918    1918-1935         NaN
# 2        1.000          -1      NaN     1918    1918-1935         NaN
# 3        1.000          -1      NaN     1918    1918-1935         NaN
# 4        0.918       30800    0.684     1918    1918-1935         NaN
# ..         ...         ...      ...      ...          ...         ...
# 683        NaN       22917    0.642     1918    1918-1935         NaN
# 684      0.370       22371    0.652     1918    1918-1935         NaN
# 685      0.556       19172    0.494     1918    1918-1935         NaN
# 686        NaN       21797    0.605     1918    1918-1935         NaN
# 687      0.752       18443    0.586     1918    1918-1935         NaN
#
# [688 rows x 20 columns]

# %% [markdown]
# Looks like some of these fields are stored as strings when they should be numeric. Let's coerce them to be numbers:

# %%
def coerce_numeric_values_and_fix_field_names(df):
    df.rename(columns={"lib_votes ": "lib_votes"}, inplace=True)
    df.rename(columns={"turnout ": "turnout"}, inplace=True)
    for numeric_field in ("seats", "electorate", "con_votes", "con_share", "lib_votes", "lib_share", "lab_votes", "lab_share", "natSW_votes", "natSW_share", "oth_votes", "oth_share", "total_votes", "turnout", "election"):
        df[numeric_field] = pd.to_numeric(df[numeric_field], errors="coerce")
    return df
df = coerce_numeric_values_and_fix_field_names(df)

# %%
constituencies_with_more_than_one_seat_1918 = df[(df["seats"] > 1) & (df["election"] == 1918)]
constituencies_with_more_than_one_seat_1918
# Out:
#     constituency_id  seats               constituency_name country/region  \
# 4               NaN      2                       Cork City        Ireland
# 68               86      2                       Blackburn     North West
# 70               90      2                          Bolton     North West
# 79               97      2                        Brighton     South East
# 99              NaN      2            Cambridge University     University
# 120              12      2                  City Of London         London
# 122             NaN      2   Combined English Universities     University
# 123             NaN      3  Combined Scottish Universities     University
# 145             117      2                           Derby  East Midlands
# 186             NaN      2               Dublin University     University
# 191             552      2                          Dundee       Scotland
# 472             197      2                         Norwich        Eastern
# 482             202      2                          Oldham     North West
# 485             NaN      2               Oxford University     University
# 503             210      2                         Preston     North West
# 546             232      2                     Southampton     South East
# 570             236      2                       Stockport     North West
# 581             241      2                      Sunderland     North East
#
#      electorate  con_votes  con_share  lib_votes  lib_share  lab_votes  \
# 4       45017.0     2519.0      0.082        NaN        NaN        NaN
# 68      61972.0    15605.0      0.337        NaN        NaN    14134.0
# 70      80888.0        NaN        NaN        NaN        NaN       -1.0
# 79      82449.0    33325.0      0.787        NaN        NaN     9027.0
# 99       9282.0     3925.0      0.677        NaN        NaN      640.0
# 120         NaN       -2.0        NaN        NaN        NaN        NaN
# 122      2357.0      303.0      0.152        NaN        NaN      366.0
# 123     27283.0     7005.0      0.580        NaN        NaN     1581.0
# 145     61538.0     9867.0      0.245     7102.0      0.176    16065.0
# 186      4541.0     1904.0      0.645        NaN        NaN        NaN
# 191     83676.0        NaN        NaN        NaN        NaN    16295.0
# 472     60342.0        NaN        NaN    13406.0      0.402     5895.0
# 482     71378.0    13748.0      0.323     5106.0      0.120    10332.0
# 485      7907.0     4487.0      0.806      742.0      0.133      335.0
# 503     57795.0    18772.0      0.466    10389.0      0.258    11103.0
# 546     75334.0    10227.0      0.253        NaN        NaN     7738.0
# 570     60777.0        NaN        NaN        NaN        NaN        NaN
# 581     73121.0    17226.0      0.418        NaN        NaN     6664.0
#
#      lab_share  natSW_votes  natSW_share  oth_votes  oth_share  total_votes  \
# 4          NaN          NaN          NaN    28281.0      0.918      30800.0
# 68       0.305          NaN          NaN    16638.0      0.359      46372.0
# 70         NaN          NaN          NaN       -1.0     -1.000          NaN
# 79       0.213          NaN          NaN        NaN        NaN      42352.0
# 99       0.110          NaN          NaN     1229.0      0.212       5794.0
# 120        NaN          NaN          NaN        NaN        NaN         -2.0
# 122      0.184          NaN          NaN     1325.0      0.664       1994.0
# 123      0.131          NaN          NaN     3499.0      0.290      12085.0
# 145      0.398          NaN          NaN     7287.0      0.181      40322.0
# 186        NaN          NaN          NaN     1050.0      0.355       2954.0
# 191      0.418          NaN          NaN    21788.0      0.558      39025.0
# 472      0.177          NaN          NaN    13981.0      0.420      33313.0
# 482      0.243          NaN          NaN    13316.0      0.313      42503.0
# 485      0.060          NaN          NaN        NaN        NaN       5564.0
# 503      0.276          NaN          NaN        NaN        NaN      40263.0
# 546      0.191          NaN          NaN    22512.0      0.556      40486.0
# 570        NaN          NaN          NaN       -1.0        NaN          NaN
# 581      0.162          NaN          NaN    17321.0      0.420      41212.0
#
#      turnout  election boundary_set Unnamed: 19
# 4      0.684    1918.0    1918-1935         NaN
# 68     0.748    1918.0    1918-1935         NaN
# 70       NaN    1918.0    1918-1935         NaN
# 79     0.514    1918.0    1918-1935         NaN
# 99     0.624    1918.0    1918-1935         NaN
# 120      NaN    1918.0    1918-1935         NaN
# 122    0.846    1918.0    1918-1935         NaN
# 123    0.470    1918.0    1918-1935         NaN
# 145    0.655    1918.0    1918-1935         NaN
# 186    0.651    1918.0    1918-1935         NaN
# 191    0.466    1918.0    1918-1935         NaN
# 472    0.552    1918.0    1918-1935         NaN
# 482    0.595    1918.0    1918-1935         NaN
# 485    0.704    1918.0    1918-1935         NaN
# 503    0.696    1918.0    1918-1935         NaN
# 546    0.537    1918.0    1918-1935         NaN
# 570      NaN    1918.0    1918-1935         NaN
# 581    0.564    1918.0    1918-1935         NaN

# %%
len(constituencies_with_more_than_one_seat_1918)
# Out:
# 18

# %% [markdown]
# So there are were 17 constituencies in 1918 that returned 2 seats and 1 that returned 3(!), making for 37 seats in total.

# %%
constituencies_results_1918["seats"].sum()
# Out:
# np.int64(707)

# %%
37/707*100
# Out:
# 5.233380480905233

# %% [markdown]
# So 5.2% of seats came from these "double constituencies" in 1918. Potentially enough to have an impact on the outcome of the election. While this is annoying, it hopefully shouldn´t compromise my model too much if I assume that all constituencies only return 1 seat, as in the modern UK electoral system.

# %% [markdown]
# #### Election Year Weirdness and NaN Values in Vote Counts

# %% [markdown]
# Another major annoyance in the 1918 results at least is that a lot of them have NaN values in the vote counts. This makes them pretty much unusable for my model, so I'm going to completely ignore all elections where this kind of data is missing. Let's go through all of the elections I have data for and see which ones have usable vote count data:

# %%
elections = df["election"].unique()
elections
# Out:
# array([1918., 1922., 1923., 1924., 1929., 1931., 1935., 1945., 1950.,
#        1951., 1955., 1959., 1964., 1966., 1970., 1979., 1983., 1987.,
#        1992., 1997., 2001., 2005., 2010., 2015., 2017., 2019.,   nan])

# %% [markdown]
# Well that's interesting, why is theres such a big gap between the 1970 and 1979 elections? Looking online I can see that there were 2 elections in 1974. That may be the source of the issue. Let's reload the data frame and have another look.

# %%
df = load_election_results_csv()
elections = df["election"].unique()
elections
# Out:
# array(['1918', '1922', '1923', '1924', '1929', '1931', '1935', '1945',
#        '1950', '1951', '1955', '1959', '1964', '1966', '1970', '1979',
#        '1983', '1987', '1992', '1997', '2001', '2005', '2010', '2015',
#        '2017', '2019', '1974F', '1974O'], dtype=object)

# %% [markdown]
# Okay, so the 2 elections in 1974 are referred to as 1974F (February) and 1974O (October). This makes sense, but I'd still like to have a numerical value for the election year. So instead I will replace these values with 1974.1 1974.2 respectively. Then coerce all the numerical values again.

# %%
df["election"] = df["election"].replace("1974F", 1974.1)
df["election"] = df["election"].replace("1974O", 1974.2)
elections = df["election"].unique()
elections
# Out:
# array(['1918', '1922', '1923', '1924', '1929', '1931', '1935', '1945',
#        '1950', '1951', '1955', '1959', '1964', '1966', '1970', '1979',
#        '1983', '1987', '1992', '1997', '2001', '2005', '2010', '2015',
#        '2017', '2019', 1974.1, 1974.2], dtype=object)

# %%
df = coerce_numeric_values_and_fix_field_names(df)
elections = df["election"].unique()
elections
# Out:
# array([1918. , 1922. , 1923. , 1924. , 1929. , 1931. , 1935. , 1945. ,
#        1950. , 1951. , 1955. , 1959. , 1964. , 1966. , 1970. , 1979. ,
#        1983. , 1987. , 1992. , 1997. , 2001. , 2005. , 2010. , 2015. ,
#        2017. , 2019. , 1974.1, 1974.2])

# %% [markdown]
# Right, now let's find all elections where NaN values are included in vote counts:
